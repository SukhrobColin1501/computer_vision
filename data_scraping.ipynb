# %% [markdown]
# <a href="https://colab.research.google.com/github/SukhrobColin1501/computer_vision/blob/main/data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.advantour.com/img/uzbekistan/culture/uzbekistan-culture-dance.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://civilisable.com/wp-content/uploads/2024/09/Uzbek-traditional-clothing17.9.2024.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/7c/c7/63/7cc763fa306a83c23c3e1e9ac9ee6755.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from http://www.advantour.com/img/uzbekistan/culture/uzbek-dance8.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://s-media-cache-ak0.pinimg.com/736x/31/52/cc/3152ccf7c7ac055787b5db5699f5f542.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://uzbek-travel.com/images/uz/Tours/Classic_7_days/shutterstock_82633213.jpg
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_filename = os.path.join(target_dir, filename)

    shutil.move(src_file, dst_filename)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 60 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.licious.in/blog/wp-content/uploads/2020/12/Turkish-Kebabs-min.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/f9/4d/9b/f94d9bc8f56d3d0302fc7e727947eb0d.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://www.thespruceeats.com/thmb/47Y9vapBkwe_98TIiueYFB3OObc=/2059x2059/filters:no_upscale():max_bytes(150000):strip_icc()/aIMG_0756fsq-5aebd1ddc0647100364ee63a.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://img.freepik.com/premium-photo/doner-kebab-doner-kebap-fast-food-meal-flatbread-with-fries-wooden-board_770123-5.jpg?w=2000
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://dirtydishesmessykisses.com/wp-content/uploads/2024/11/authentic-turkish-doner-kebab-recipe-1732017060.jpg
# [%] File Downloaded!
#
# ...

# %%
import os
import shutil

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir, exist_ok=True)

for filename in os.listdir(source_dir):
    src_file = os.path.join(source_dir, filename)
    dst_filename = os.path.join(target_dir, filename)

    shutil.move(src_file, dst_filename)
